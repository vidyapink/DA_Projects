# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\DELL\Downloads\youtube\INvideos.csv')

# %%
## To check data

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc           NaT
# 1  zUZ1z7FwLc8           NaT
# 2  10L1hZ9qa58           NaT
# 3  N1vE8iiEg64           NaT
# 4  kJzGH0PVQHQ           NaT
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#   category_id              publish_time  \
# 0           1 2017-11-12 12:20:39+00:00
# 1          25 2017-11-13 05:43:56+00:00
# 2          24 2017-11-12 15:48:08+00:00
# 3          23 2017-11-12 07:08:48+00:00
# 4          24 2017-11-13 01:14:16+00:00
#
#                                                 tags     views  likes  \
# ...

# %%
## To check rows and columns

# %%
df.shape
# Out:
# (37352, 16)

# %%
# to check null values

# %%
df.isnull().sum()
# Out:
# video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# thumbnail_link              0
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               561
# dtype: int64

# %%
## TO check data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37352 entries, 0 to 37351
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37352 non-null  object
#  1   trending_date           37352 non-null  object
#  2   title                   37352 non-null  object
#  3   channel_title           37352 non-null  object
#  4   category_id             37352 non-null  int64
#  5   publish_time            37352 non-null  object
#  6   tags                    37352 non-null  object
#  7   views                   37352 non-null  int64
#  8   likes                   37352 non-null  int64
#  9   dislikes                37352 non-null  int64
#  10  comment_count           37352 non-null  int64
#  11  thumbnail_link          37352 non-null  object
#  12  comments_disabled       37352 non-null  bool
#  13  ratings_disabled        37352 non-null  bool
# ...

# %%
## to check statistics of data

# %%
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  37352.000000  3.735200e+04  3.735200e+04  3.735200e+04    37352.00000
# mean      21.576596  1.060478e+06  2.708272e+04  1.665082e+03     2676.99743
# std        6.556593  3.184932e+06  9.714510e+04  1.607617e+04    14868.31713
# min        1.000000  4.024000e+03  0.000000e+00  0.000000e+00        0.00000
# 25%       23.000000  1.239155e+05  8.640000e+02  1.080000e+02       81.00000
# 50%       24.000000  3.045860e+05  3.069000e+03  3.260000e+02      329.00000
# 75%       24.000000  7.992912e+05  1.377425e+04  1.019250e+03     1285.00000
# max       43.000000  1.254322e+08  2.912710e+06  1.545017e+06   827755.00000

# %%
df["category_id"]=df["category_id"].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37352 entries, 0 to 37351
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37352 non-null  object
#  1   trending_date           37352 non-null  object
#  2   title                   37352 non-null  object
#  3   channel_title           37352 non-null  object
#  4   category_id             37352 non-null  object
#  5   publish_time            37352 non-null  object
#  6   tags                    37352 non-null  object
#  7   views                   37352 non-null  int64
#  8   likes                   37352 non-null  int64
#  9   dislikes                37352 non-null  int64
#  10  comment_count           37352 non-null  int64
#  11  thumbnail_link          37352 non-null  object
#  12  comments_disabled       37352 non-null  bool
#  13  ratings_disabled        37352 non-null  bool
# ...

# %% [markdown]
# ##### to change datatype to datetime

# %%
df["publish_time"] = pd.to_datetime(df["publish_time"])

# %%
df.head(10)
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc      17.14.11
# 1  zUZ1z7FwLc8      17.14.11
# 2  10L1hZ9qa58      17.14.11
# 3  N1vE8iiEg64      17.14.11
# 4  kJzGH0PVQHQ      17.14.11
# 5  il_pSa5l98w      17.14.11
# 6  7MxiQ4v0EnE      17.14.11
# 7  c64I9HNpiOY      17.14.11
# 8  KObFEYCaRx8      17.14.11
# 9  g8QsfJhFpjY      17.14.11
#
#                                                title     channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...   Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...           HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...              TFPC
# 3                     Eruma Saani | Tamil vs English       Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...        Filmylooks
# 5  MCA (Middle Class Abbayi) TEASER - Nani,Sai Pa...          Dil Raju
# 6  Daang ( Full Video ) | Mankirt Aulakh | Sukh S...     Speed Records
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37352 entries, 0 to 37351
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37352 non-null  object
#  1   trending_date           37352 non-null  object
#  2   title                   37352 non-null  object
#  3   channel_title           37352 non-null  object
#  4   category_id             37352 non-null  object
#  5   publish_time            37352 non-null  datetime64[ns, UTC]
#  6   tags                    37352 non-null  object
#  7   views                   37352 non-null  int64
#  8   likes                   37352 non-null  int64
#  9   dislikes                37352 non-null  int64
#  10  comment_count           37352 non-null  int64
#  11  thumbnail_link          37352 non-null  object
#  12  comments_disabled       37352 non-null  bool
#  13  ratings_disabled        37352 non-null  bool
# ...

# %% [markdown]
# #### Converted views values in Cr

# %%
df["views"]=df["views"]/10000000

# %% [markdown]
# #### TO check which channel having more views

# %%
df1=df.groupby("channel_title",as_index=False)["views"].sum()

# %%
df1.sort_values("views",ascending=False)
# Out:
#              channel_title       views
# 1052              T-Series  212.460791
# 631   Marvel Entertainment  128.039620
# 356           FoxStarHindi  126.080762
# 78            Amit Bhadana  102.425217
# 1019         Speed Records   80.173941
# ...                    ...         ...
# 795                Pakkatv    0.001344
# 894           Reporter Roy    0.001182
# 1282        Viral in India    0.001139
# 1315   Wide Angle Pictures    0.001134
# 740             News VIdeo    0.000757
#
# [1426 rows x 2 columns]

# %% [markdown]
# TO check average views of channels

# %%
df2=df.groupby("channel_title",as_index=False)["views"].mean()

# %%
df2.sort_values("views",ascending=False)
# Out:
#                     channel_title     views
# 1339            YouTube Spotlight  8.226435
# 1126              TaylorSwiftVEVO  2.864121
# 1013  Sony Pictures Entertainment  2.271359
# 356                  FoxStarHindi  2.251442
# 631          Marvel Entertainment  1.969840
# ...                           ...       ...
# 894                  Reporter Roy  0.001182
# 1282               Viral in India  0.001139
# 1315          Wide Angle Pictures  0.001134
# 768              OneVision Telugu  0.001033
# 740                    News VIdeo  0.000757
#
# [1426 rows x 2 columns]

# %% [markdown]
# ##### To check time period if data

# %%
df['trending_date'] = pd.to_datetime(df['trending_date'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37352 entries, 0 to 37351
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37352 non-null  object
#  1   trending_date           13867 non-null  datetime64[ns]
#  2   title                   37352 non-null  object
#  3   channel_title           37352 non-null  object
#  4   category_id             37352 non-null  object
#  5   publish_time            37352 non-null  datetime64[ns, UTC]
#  6   tags                    37352 non-null  object
#  7   views                   37352 non-null  float64
#  8   likes                   37352 non-null  int64
#  9   dislikes                37352 non-null  int64
#  10  comment_count           37352 non-null  int64
#  11  thumbnail_link          37352 non-null  object
#  12  comments_disabled       37352 non-null  bool
#  13  ratings_disabled        37352 non-null  bool
# ...

# %%
print(df["trending_date"].min())
print(df["trending_date"].max())
# Out:
# 2001-01-18 00:00:00
# 2012-12-17 00:00:00

# %%
df3=(df["channel_title"].unique())

# %%
df3.shape
# Out:
# (1426,)

# %%
(df[df.duplicated])
# Out:
#           video_id trending_date  \
# 1689   YAzs-timxnI           NaT
# 1690   ZJDMWVZta3M           NaT
# 1691   RVpnz8mbVDI           NaT
# 1692   CfZSYm-mFgI           NaT
# 1693   m1PDqdLQMv8           NaT
# ...            ...           ...
# 37347  iNHecA3PJCo           NaT
# 37348  dpPmPbhcslM           NaT
# 37349  mV6aztP58f8           NaT
# 37350  qxqDNP1bDEw           NaT
# 37351  wERgpPK44w0           NaT
#
#                                                    title        channel_title  \
# 1689   Swag Se Swagat Song | Official Teaser | Salman...                  YRF
# 1690               Incredibles 2 Official Teaser Trailer         Disney•Pixar
# 1691   Jaisi Karni Waisi Bharni - | Lalit Shokeen Fil...       LShokeen Films
# 1692   Bomma Adhirindhi Song Trailer | Jawaan Telugu ...  Arunachal Creations
# 1693           Miss World 2017 Top 5 Question and Answer      Beauty Pageants
# ...                                                  ...                  ...
# ...

# %%
print("Shape:", df.shape)
print("\nMissing values:\n", df.isnull().sum())
print("\nDuplicate rows:", df.duplicated().sum())
print("\nData types:\n", df.dtypes)
print("\nSample values:\n", df.head())
# Out:
# Shape: (37352, 16)
#
# Missing values:
#  video_id                      0
# trending_date             23485
# title                         0
# channel_title                 0
# category_id                   0
# publish_time                  0
# tags                          0
# views                         0
# likes                         0
# dislikes                      0
# comment_count                 0
# thumbnail_link                0
# comments_disabled             0
# ratings_disabled              0
# video_error_or_removed        0
# description                 561
# dtype: int64
#
# Duplicate rows: 4263
#
# Data types:
#  video_id                               object
# trending_date                  datetime64[ns]
# title                                  object
# channel_title                          object
# category_id                            object
# publish_time              datetime64[ns, UTC]
# tags                                   object
# ...

# %% [markdown]
# ###### To check more disliked channel

# %%
df6=df.groupby("channel_title",as_index=False)["dislikes"].sum()

# %%
df6.sort_values(by="dislikes",ascending=False)
# Out:
#                 channel_title  dislikes
# 1339        YouTube Spotlight   6865746
# 1052                 T-Series   2650896
# 1198            Tips Official   2370526
# 78               Amit Bhadana   2305446
# 949         Salman Khan Films   1294276
# ...                       ...       ...
# 449                    I News         0
# 455                 Impact TV         0
# 1211           Top News World         0
# 170            Bornali NewsBD         0
# 507   Kannada Bhakthi Channel         0
#
# [1426 rows x 2 columns]
